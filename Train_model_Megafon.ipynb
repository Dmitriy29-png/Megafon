# %%
import pandas as pd
import numpy as np
import catboost as catb

import dask.dataframe as dd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from imblearn.under_sampling import RandomUnderSampler
from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

from sklearn.metrics import f1_score, classification_report
from sklearn.feature_selection import SelectFromModel

import pickle

# %%
from until import ColumnSelector, preprocess_data_train, preprocess_data_test, select_type_cols

# %%
TRAIN_DATA = 'data/data_train.csv'
FEATURES_DATA = 'data/features.csv'
RANDOM_STATE = 21

# %% [markdown]
# ### Data preparation

# %%
train_df = pd.read_csv(TRAIN_DATA)

# %%
data_train, true_offers_ids = preprocess_data_train(train_df, FEATURES_DATA)

# %%
with open("data/offer_mark.txt", "w") as file:
    print(*true_offers_ids, file=file, sep="\n")

# %%
data_prelim = data_train.copy()

X_train = data_prelim.drop('target', axis=1)
y_train = data_prelim['target']

# %%
f_all, f_binary, f_categorical, f_numeric = select_type_cols(X_train)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_train, y_train, test_size=0.20, random_state=42, shuffle=False)

# %%
ros = RandomUnderSampler(random_state=42)
X_train, Y_train = ros.fit_resample(X_train, Y_train)

print("Train")
print(Y_train.value_counts()/y_train.shape[0])
# Out:
# Train
# 0.0    0.056824
# 1.0    0.056824
# Name: target, dtype: float64

# %% [markdown]
# ### Model Training

# %%
f_prep_pipeline = make_pipeline(
    ColumnSelector(columns=f_all),
    FeatureUnion(transformer_list=[
        ("numeric_features", make_pipeline(
            ColumnSelector(f_numeric),
            SimpleImputer(strategy="mean"),
            StandardScaler()
        )),
        ("categorical_features", make_pipeline(
            ColumnSelector(f_categorical),
            SimpleImputer(strategy="most_frequent"),
            OneHotEncoder(handle_unknown='ignore')
        )),
        ("boolean_features", make_pipeline(
            ColumnSelector(f_binary),
        ))
    ])
)

# %%
catb_model = catb.CatBoostClassifier(random_state=21,
                                    score_function='L2',
                                    depth = 7,
                                    eval_metric='AUC',
                                    l2_leaf_reg = 4,
                                    learning_rate=0.01,
                                    custom_metric=['Precision', 'Recall'],
                                    iterations=1000,                                    
                                )

# %%
cat_boost_pipe = make_pipeline(
    f_prep_pipeline,
    catb_model
)

# %%
cat_boost_pipe.fit(X_train, Y_train)
# Out:
# 0:	total: 248ms	remaining: 4m 7s
# 1:	total: 316ms	remaining: 2m 37s
# 2:	total: 384ms	remaining: 2m 7s
# 3:	total: 454ms	remaining: 1m 53s
# 4:	total: 524ms	remaining: 1m 44s
# 5:	total: 592ms	remaining: 1m 38s
# 6:	total: 665ms	remaining: 1m 34s
# 7:	total: 736ms	remaining: 1m 31s
# 8:	total: 804ms	remaining: 1m 28s
# 9:	total: 874ms	remaining: 1m 26s
# 10:	total: 944ms	remaining: 1m 24s
# 11:	total: 1.01s	remaining: 1m 23s
# 12:	total: 1.09s	remaining: 1m 22s
# 13:	total: 1.16s	remaining: 1m 21s
# 14:	total: 1.23s	remaining: 1m 20s
# 15:	total: 1.3s	remaining: 1m 19s
# 16:	total: 1.37s	remaining: 1m 19s
# 17:	total: 1.44s	remaining: 1m 18s
# 18:	total: 1.51s	remaining: 1m 17s
# 19:	total: 1.58s	remaining: 1m 17s
# 20:	total: 1.65s	remaining: 1m 16s
# 21:	total: 1.72s	remaining: 1m 16s
# 22:	total: 1.78s	remaining: 1m 15s
# 23:	total: 1.85s	remaining: 1m 15s
# 24:	total: 1.92s	remaining: 1m 15s
# 25:	total: 1.99s	remaining: 1m 14s
# 26:	total: 2.07s	remaining: 1m 14s
# 27:	total: 2.14s	remaining: 1m 14s
# 28:	total: 2.21s	remaining: 1m 13s
# 29:	total: 2.27s	remaining: 1m 13s
# 30:	total: 2.35s	remaining: 1m 13s
# 31:	total: 2.41s	remaining: 1m 13s
# 32:	total: 2.48s	remaining: 1m 12s
# 33:	total: 2.55s	remaining: 1m 12s
# 34:	total: 2.62s	remaining: 1m 12s
# 35:	total: 2.69s	remaining: 1m 11s
# 36:	total: 2.75s	remaining: 1m 11s
# 37:	total: 2.82s	remaining: 1m 11s
# 38:	total: 2.89s	remaining: 1m 11s
# 39:	total: 2.96s	remaining: 1m 11s
# 40:	total: 3.03s	remaining: 1m 10s
# 41:	total: 3.1s	remaining: 1m 10s
# 42:	total: 3.17s	remaining: 1m 10s
# 43:	total: 3.24s	remaining: 1m 10s
# 44:	total: 3.31s	remaining: 1m 10s
# 45:	total: 3.39s	remaining: 1m 10s
# 46:	total: 3.48s	remaining: 1m 10s
# 47:	total: 3.56s	remaining: 1m 10s
# 48:	total: 3.66s	remaining: 1m 10s
# 49:	total: 3.75s	remaining: 1m 11s
# 50:	total: 3.83s	remaining: 1m 11s
# 51:	total: 3.9s	remaining: 1m 11s
# 52:	total: 3.98s	remaining: 1m 11s
# 53:	total: 4.07s	remaining: 1m 11s
# 54:	total: 4.14s	remaining: 1m 11s
# 55:	total: 4.22s	remaining: 1m 11s
# 56:	total: 4.3s	remaining: 1m 11s
# 57:	total: 4.39s	remaining: 1m 11s
# 58:	total: 4.48s	remaining: 1m 11s
# 59:	total: 4.55s	remaining: 1m 11s
# 60:	total: 4.62s	remaining: 1m 11s
# 61:	total: 4.69s	remaining: 1m 10s
# 62:	total: 4.76s	remaining: 1m 10s
# 63:	total: 4.82s	remaining: 1m 10s
# 64:	total: 4.9s	remaining: 1m 10s
# 65:	total: 4.97s	remaining: 1m 10s
# 66:	total: 5.04s	remaining: 1m 10s
# 67:	total: 5.1s	remaining: 1m 9s
# 68:	total: 5.17s	remaining: 1m 9s
# 69:	total: 5.24s	remaining: 1m 9s
# 70:	total: 5.31s	remaining: 1m 9s
# 71:	total: 5.37s	remaining: 1m 9s
# 72:	total: 5.44s	remaining: 1m 9s
# 73:	total: 5.51s	remaining: 1m 8s
# 74:	total: 5.58s	remaining: 1m 8s
# 75:	total: 5.64s	remaining: 1m 8s
# 76:	total: 5.71s	remaining: 1m 8s
# 77:	total: 5.78s	remaining: 1m 8s
# 78:	total: 5.85s	remaining: 1m 8s
# 79:	total: 5.92s	remaining: 1m 8s
# 80:	total: 5.99s	remaining: 1m 7s
# 81:	total: 6.05s	remaining: 1m 7s
# 82:	total: 6.12s	remaining: 1m 7s
# 83:	total: 6.19s	remaining: 1m 7s
# 84:	total: 6.26s	remaining: 1m 7s
# 85:	total: 6.32s	remaining: 1m 7s
# 86:	total: 6.39s	remaining: 1m 7s
# 87:	total: 6.46s	remaining: 1m 6s
# 88:	total: 6.53s	remaining: 1m 6s
# 89:	total: 6.59s	remaining: 1m 6s
# 90:	total: 6.66s	remaining: 1m 6s
# 91:	total: 6.73s	remaining: 1m 6s
# 92:	total: 6.79s	remaining: 1m 6s
# 93:	total: 6.86s	remaining: 1m 6s
# 94:	total: 6.93s	remaining: 1m 6s
# 95:	total: 7s	remaining: 1m 5s
# 96:	total: 7.07s	remaining: 1m 5s
# 97:	total: 7.14s	remaining: 1m 5s
# 98:	total: 7.21s	remaining: 1m 5s
# 99:	total: 7.27s	remaining: 1m 5s
# 100:	total: 7.34s	remaining: 1m 5s
# 101:	total: 7.41s	remaining: 1m 5s
# 102:	total: 7.48s	remaining: 1m 5s
# 103:	total: 7.55s	remaining: 1m 5s
# 104:	total: 7.62s	remaining: 1m 4s
# 105:	total: 7.68s	remaining: 1m 4s
# 106:	total: 7.75s	remaining: 1m 4s
# 107:	total: 7.83s	remaining: 1m 4s
# 108:	total: 7.9s	remaining: 1m 4s
# 109:	total: 7.96s	remaining: 1m 4s
# 110:	total: 8.03s	remaining: 1m 4s
# 111:	total: 8.1s	remaining: 1m 4s
# 112:	total: 8.17s	remaining: 1m 4s
# 113:	total: 8.23s	remaining: 1m 4s
# 114:	total: 8.31s	remaining: 1m 3s
# 115:	total: 8.38s	remaining: 1m 3s
# 116:	total: 8.44s	remaining: 1m 3s
# 117:	total: 8.51s	remaining: 1m 3s
# 118:	total: 8.58s	remaining: 1m 3s
# 119:	total: 8.65s	remaining: 1m 3s
# 120:	total: 8.72s	remaining: 1m 3s
# 121:	total: 8.78s	remaining: 1m 3s
# 122:	total: 8.85s	remaining: 1m 3s
# 123:	total: 8.92s	remaining: 1m 2s
# 124:	total: 8.99s	remaining: 1m 2s
# 125:	total: 9.05s	remaining: 1m 2s
# 126:	total: 9.12s	remaining: 1m 2s
# 127:	total: 9.19s	remaining: 1m 2s
# 128:	total: 9.25s	remaining: 1m 2s
# 129:	total: 9.32s	remaining: 1m 2s
# 130:	total: 9.39s	remaining: 1m 2s
# 131:	total: 9.46s	remaining: 1m 2s
# 132:	total: 9.53s	remaining: 1m 2s
# 133:	total: 9.59s	remaining: 1m 2s
# 134:	total: 9.66s	remaining: 1m 1s
# 135:	total: 9.73s	remaining: 1m 1s
# 136:	total: 9.79s	remaining: 1m 1s
# 137:	total: 9.87s	remaining: 1m 1s
# 138:	total: 9.93s	remaining: 1m 1s
# 139:	total: 10s	remaining: 1m 1s
# 140:	total: 10.1s	remaining: 1m 1s
# 141:	total: 10.1s	remaining: 1m 1s
# 142:	total: 10.2s	remaining: 1m 1s
# 143:	total: 10.3s	remaining: 1m 1s
# 144:	total: 10.3s	remaining: 1m
# 145:	total: 10.4s	remaining: 1m
# 146:	total: 10.5s	remaining: 1m
# 147:	total: 10.5s	remaining: 1m
# 148:	total: 10.6s	remaining: 1m
# 149:	total: 10.7s	remaining: 1m
# 150:	total: 10.8s	remaining: 1m
# 151:	total: 10.8s	remaining: 1m
# 152:	total: 10.9s	remaining: 1m
# 153:	total: 11s	remaining: 1m
# 154:	total: 11.1s	remaining: 1m
# 155:	total: 11.1s	remaining: 1m
# 156:	total: 11.2s	remaining: 1m
# 157:	total: 11.3s	remaining: 60s
# 158:	total: 11.3s	remaining: 59.9s
# 159:	total: 11.4s	remaining: 59.8s
# 160:	total: 11.5s	remaining: 59.7s
# 161:	total: 11.5s	remaining: 59.7s
# 162:	total: 11.6s	remaining: 59.6s
# 163:	total: 11.7s	remaining: 59.5s
# 164:	total: 11.7s	remaining: 59.4s
# 165:	total: 11.8s	remaining: 59.3s
# 166:	total: 11.9s	remaining: 59.3s
# 167:	total: 11.9s	remaining: 59.2s
# 168:	total: 12s	remaining: 59.1s
# 169:	total: 12.1s	remaining: 59s
# 170:	total: 12.2s	remaining: 58.9s
# 171:	total: 12.2s	remaining: 58.8s
# 172:	total: 12.3s	remaining: 58.7s
# 173:	total: 12.3s	remaining: 58.6s
# 174:	total: 12.4s	remaining: 58.5s
# 175:	total: 12.5s	remaining: 58.4s
# 176:	total: 12.5s	remaining: 58.3s
# 177:	total: 12.6s	remaining: 58.2s
# 178:	total: 12.7s	remaining: 58.1s
# 179:	total: 12.7s	remaining: 58s
# 180:	total: 12.8s	remaining: 57.9s
# 181:	total: 12.9s	remaining: 57.8s
# 182:	total: 12.9s	remaining: 57.7s
# 183:	total: 13s	remaining: 57.6s
# 184:	total: 13.1s	remaining: 57.6s
# 185:	total: 13.1s	remaining: 57.5s
# 186:	total: 13.2s	remaining: 57.4s
# 187:	total: 13.3s	remaining: 57.3s
# 188:	total: 13.3s	remaining: 57.2s
# 189:	total: 13.4s	remaining: 57.1s
# 190:	total: 13.5s	remaining: 57s
# 191:	total: 13.5s	remaining: 56.9s
# 192:	total: 13.6s	remaining: 56.9s
# 193:	total: 13.7s	remaining: 56.8s
# 194:	total: 13.7s	remaining: 56.7s
# 195:	total: 13.8s	remaining: 56.6s
# 196:	total: 13.9s	remaining: 56.5s
# 197:	total: 13.9s	remaining: 56.4s
# 198:	total: 14s	remaining: 56.3s
# 199:	total: 14.1s	remaining: 56.2s
# 200:	total: 14.1s	remaining: 56.1s
# 201:	total: 14.2s	remaining: 56.1s
# 202:	total: 14.3s	remaining: 56s
# 203:	total: 14.3s	remaining: 55.9s
# 204:	total: 14.4s	remaining: 55.8s
# 205:	total: 14.5s	remaining: 55.7s
# 206:	total: 14.5s	remaining: 55.6s
# 207:	total: 14.6s	remaining: 55.6s
# 208:	total: 14.7s	remaining: 55.5s
# 209:	total: 14.7s	remaining: 55.4s
# 210:	total: 14.8s	remaining: 55.3s
# 211:	total: 14.9s	remaining: 55.2s
# 212:	total: 14.9s	remaining: 55.1s
# 213:	total: 15s	remaining: 55s
# 214:	total: 15s	remaining: 54.9s
# 215:	total: 15.1s	remaining: 54.9s
# 216:	total: 15.2s	remaining: 54.8s
# 217:	total: 15.2s	remaining: 54.7s
# 218:	total: 15.3s	remaining: 54.6s
# 219:	total: 15.4s	remaining: 54.5s
# 220:	total: 15.5s	remaining: 54.5s
# 221:	total: 15.5s	remaining: 54.4s
# 222:	total: 15.6s	remaining: 54.3s
# 223:	total: 15.7s	remaining: 54.2s
# 224:	total: 15.7s	remaining: 54.1s
# 225:	total: 15.8s	remaining: 54s
# 226:	total: 15.8s	remaining: 54s
# 227:	total: 15.9s	remaining: 53.9s
# 228:	total: 16s	remaining: 53.8s
# 229:	total: 16s	remaining: 53.7s
# 230:	total: 16.1s	remaining: 53.6s
# 231:	total: 16.2s	remaining: 53.5s
# 232:	total: 16.2s	remaining: 53.4s
# 233:	total: 16.3s	remaining: 53.4s
# 234:	total: 16.4s	remaining: 53.3s
# 235:	total: 16.4s	remaining: 53.2s
# 236:	total: 16.5s	remaining: 53.1s
# 237:	total: 16.6s	remaining: 53s
# 238:	total: 16.6s	remaining: 53s
# 239:	total: 16.7s	remaining: 52.9s
# 240:	total: 16.8s	remaining: 52.8s
# 241:	total: 16.8s	remaining: 52.7s
# 242:	total: 16.9s	remaining: 52.6s
# 243:	total: 16.9s	remaining: 52.5s
# 244:	total: 17s	remaining: 52.4s
# 245:	total: 17.1s	remaining: 52.4s
# 246:	total: 17.2s	remaining: 52.3s
# 247:	total: 17.2s	remaining: 52.2s
# 248:	total: 17.3s	remaining: 52.2s
# 249:	total: 17.4s	remaining: 52.1s
# 250:	total: 17.4s	remaining: 52s
# 251:	total: 17.5s	remaining: 51.9s
# 252:	total: 17.6s	remaining: 51.8s
# 253:	total: 17.6s	remaining: 51.8s
# 254:	total: 17.7s	remaining: 51.7s
# 255:	total: 17.8s	remaining: 51.6s
# 256:	total: 17.8s	remaining: 51.5s
# 257:	total: 17.9s	remaining: 51.5s
# 258:	total: 18s	remaining: 51.4s
# 259:	total: 18s	remaining: 51.3s
# 260:	total: 18.1s	remaining: 51.2s
# 261:	total: 18.1s	remaining: 51.1s
# 262:	total: 18.2s	remaining: 51s
# 263:	total: 18.3s	remaining: 50.9s
# 264:	total: 18.3s	remaining: 50.8s
# 265:	total: 18.4s	remaining: 50.8s
# 266:	total: 18.5s	remaining: 50.7s
# 267:	total: 18.5s	remaining: 50.6s
# 268:	total: 18.6s	remaining: 50.5s
# 269:	total: 18.6s	remaining: 50.4s
# 270:	total: 18.7s	remaining: 50.3s
# 271:	total: 18.8s	remaining: 50.2s
# 272:	total: 18.8s	remaining: 50.1s
# 273:	total: 18.9s	remaining: 50.1s
# 274:	total: 19s	remaining: 50s
# 275:	total: 19s	remaining: 49.9s
# 276:	total: 19.1s	remaining: 49.8s
# 277:	total: 19.2s	remaining: 49.8s
# 278:	total: 19.2s	remaining: 49.7s
# 279:	total: 19.3s	remaining: 49.6s
# 280:	total: 19.4s	remaining: 49.6s
# 281:	total: 19.5s	remaining: 49.5s
# 282:	total: 19.5s	remaining: 49.5s
# 283:	total: 19.6s	remaining: 49.5s
# 284:	total: 19.7s	remaining: 49.4s
# 285:	total: 19.8s	remaining: 49.4s
# 286:	total: 19.9s	remaining: 49.4s
# 287:	total: 19.9s	remaining: 49.3s
# 288:	total: 20s	remaining: 49.2s
# 289:	total: 20.1s	remaining: 49.2s
# 290:	total: 20.2s	remaining: 49.1s
# 291:	total: 20.3s	remaining: 49.1s
# 292:	total: 20.3s	remaining: 49.1s
# 293:	total: 20.4s	remaining: 49s
# 294:	total: 20.5s	remaining: 48.9s
# 295:	total: 20.5s	remaining: 48.8s
# 296:	total: 20.6s	remaining: 48.8s
# 297:	total: 20.7s	remaining: 48.7s
# 298:	total: 20.7s	remaining: 48.6s
# 299:	total: 20.8s	remaining: 48.5s
# 300:	total: 20.9s	remaining: 48.4s
# 301:	total: 20.9s	remaining: 48.4s
# 302:	total: 21s	remaining: 48.3s
# 303:	total: 21s	remaining: 48.2s
# 304:	total: 21.1s	remaining: 48.1s
# 305:	total: 21.2s	remaining: 48s
# 306:	total: 21.2s	remaining: 47.9s
# 307:	total: 21.3s	remaining: 47.8s
# 308:	total: 21.4s	remaining: 47.8s
# 309:	total: 21.4s	remaining: 47.7s
# 310:	total: 21.5s	remaining: 47.6s
# 311:	total: 21.5s	remaining: 47.5s
# 312:	total: 21.6s	remaining: 47.4s
# 313:	total: 21.7s	remaining: 47.4s
# 314:	total: 21.7s	remaining: 47.3s
# 315:	total: 21.8s	remaining: 47.2s
# 316:	total: 21.9s	remaining: 47.1s
# 317:	total: 21.9s	remaining: 47.1s
# 318:	total: 22s	remaining: 47s
# 319:	total: 22.1s	remaining: 46.9s
# 320:	total: 22.1s	remaining: 46.8s
# 321:	total: 22.2s	remaining: 46.7s
# 322:	total: 22.3s	remaining: 46.7s
# 323:	total: 22.3s	remaining: 46.6s
# 324:	total: 22.4s	remaining: 46.5s
# 325:	total: 22.5s	remaining: 46.4s
# 326:	total: 22.5s	remaining: 46.3s
# 327:	total: 22.6s	remaining: 46.2s
# 328:	total: 22.6s	remaining: 46.2s
# 329:	total: 22.7s	remaining: 46.1s
# 330:	total: 22.8s	remaining: 46s
# 331:	total: 22.8s	remaining: 45.9s
# 332:	total: 22.9s	remaining: 45.9s
# 333:	total: 23s	remaining: 45.8s
# 334:	total: 23s	remaining: 45.7s
# 335:	total: 23.1s	remaining: 45.6s
# 336:	total: 23.2s	remaining: 45.6s
# 337:	total: 23.2s	remaining: 45.5s
# 338:	total: 23.3s	remaining: 45.4s
# 339:	total: 23.3s	remaining: 45.3s
# 340:	total: 23.4s	remaining: 45.3s
# 341:	total: 23.5s	remaining: 45.2s
# 342:	total: 23.5s	remaining: 45.1s
# 343:	total: 23.6s	remaining: 45s
# 344:	total: 23.7s	remaining: 44.9s
# 345:	total: 23.7s	remaining: 44.9s
# 346:	total: 23.8s	remaining: 44.8s
# 347:	total: 23.9s	remaining: 44.7s
# 348:	total: 23.9s	remaining: 44.6s
# 349:	total: 24s	remaining: 44.5s
# 350:	total: 24s	remaining: 44.5s
# 351:	total: 24.1s	remaining: 44.4s
# 352:	total: 24.2s	remaining: 44.3s
# 353:	total: 24.2s	remaining: 44.2s
# 354:	total: 24.3s	remaining: 44.1s
# 355:	total: 24.4s	remaining: 44.1s
# 356:	total: 24.4s	remaining: 44s
# 357:	total: 24.5s	remaining: 43.9s
# 358:	total: 24.6s	remaining: 43.9s
# 359:	total: 24.6s	remaining: 43.8s
# 360:	total: 24.7s	remaining: 43.7s
# 361:	total: 24.8s	remaining: 43.6s
# 362:	total: 24.8s	remaining: 43.6s
# 363:	total: 24.9s	remaining: 43.5s
# 364:	total: 25s	remaining: 43.4s
# 365:	total: 25s	remaining: 43.4s
# 366:	total: 25.1s	remaining: 43.3s
# 367:	total: 25.1s	remaining: 43.2s
# 368:	total: 25.2s	remaining: 43.1s
# 369:	total: 25.3s	remaining: 43s
# 370:	total: 25.3s	remaining: 42.9s
# 371:	total: 25.4s	remaining: 42.9s
# 372:	total: 25.5s	remaining: 42.8s
# 373:	total: 25.5s	remaining: 42.7s
# 374:	total: 25.6s	remaining: 42.6s
# 375:	total: 25.7s	remaining: 42.6s
# 376:	total: 25.7s	remaining: 42.5s
# 377:	total: 25.8s	remaining: 42.4s
# 378:	total: 25.8s	remaining: 42.3s
# 379:	total: 25.9s	remaining: 42.3s
# 380:	total: 26s	remaining: 42.2s
# 381:	total: 26s	remaining: 42.1s
# 382:	total: 26.1s	remaining: 42s
# 383:	total: 26.2s	remaining: 42s
# 384:	total: 26.2s	remaining: 41.9s
# 385:	total: 26.3s	remaining: 41.8s
# 386:	total: 26.4s	remaining: 41.7s
# 387:	total: 26.4s	remaining: 41.7s
# 388:	total: 26.5s	remaining: 41.6s
# 389:	total: 26.6s	remaining: 41.5s
# 390:	total: 26.6s	remaining: 41.5s
# 391:	total: 26.7s	remaining: 41.4s
# 392:	total: 26.7s	remaining: 41.3s
# 393:	total: 26.8s	remaining: 41.2s
# 394:	total: 26.9s	remaining: 41.1s
# 395:	total: 26.9s	remaining: 41.1s
# 396:	total: 27s	remaining: 41s
# 397:	total: 27s	remaining: 40.9s
# 398:	total: 27.1s	remaining: 40.8s
# 399:	total: 27.2s	remaining: 40.8s
# 400:	total: 27.2s	remaining: 40.7s
# 401:	total: 27.3s	remaining: 40.6s
# 402:	total: 27.4s	remaining: 40.5s
# 403:	total: 27.4s	remaining: 40.5s
# 404:	total: 27.5s	remaining: 40.4s
# 405:	total: 27.5s	remaining: 40.3s
# 406:	total: 27.6s	remaining: 40.2s
# 407:	total: 27.7s	remaining: 40.1s
# 408:	total: 27.7s	remaining: 40.1s
# 409:	total: 27.8s	remaining: 40s
# 410:	total: 27.8s	remaining: 39.9s
# 411:	total: 27.9s	remaining: 39.8s
# 412:	total: 28s	remaining: 39.8s
# 413:	total: 28s	remaining: 39.7s
# 414:	total: 28.1s	remaining: 39.6s
# 415:	total: 28.2s	remaining: 39.5s
# 416:	total: 28.2s	remaining: 39.5s
# 417:	total: 28.3s	remaining: 39.4s
# 418:	total: 28.4s	remaining: 39.3s
# 419:	total: 28.4s	remaining: 39.2s
# 420:	total: 28.5s	remaining: 39.2s
# 421:	total: 28.5s	remaining: 39.1s
# 422:	total: 28.6s	remaining: 39s
# 423:	total: 28.7s	remaining: 38.9s
# 424:	total: 28.7s	remaining: 38.9s
# 425:	total: 28.8s	remaining: 38.8s
# 426:	total: 28.8s	remaining: 38.7s
# 427:	total: 28.9s	remaining: 38.6s
# 428:	total: 29s	remaining: 38.6s
# 429:	total: 29s	remaining: 38.5s
# 430:	total: 29.1s	remaining: 38.4s
# 431:	total: 29.2s	remaining: 38.3s
# 432:	total: 29.2s	remaining: 38.3s
# 433:	total: 29.3s	remaining: 38.2s
# 434:	total: 29.3s	remaining: 38.1s
# 435:	total: 29.4s	remaining: 38s
# 436:	total: 29.5s	remaining: 38s
# 437:	total: 29.5s	remaining: 37.9s
# 438:	total: 29.6s	remaining: 37.8s
# 439:	total: 29.6s	remaining: 37.7s
# 440:	total: 29.7s	remaining: 37.6s
# 441:	total: 29.8s	remaining: 37.6s
# 442:	total: 29.8s	remaining: 37.5s
# 443:	total: 29.9s	remaining: 37.4s
# 444:	total: 29.9s	remaining: 37.3s
# 445:	total: 30s	remaining: 37.3s
# 446:	total: 30.1s	remaining: 37.2s
# 447:	total: 30.1s	remaining: 37.1s
# 448:	total: 30.2s	remaining: 37.1s
# 449:	total: 30.3s	remaining: 37s
# 450:	total: 30.3s	remaining: 36.9s
# 451:	total: 30.4s	remaining: 36.8s
# 452:	total: 30.4s	remaining: 36.8s
# 453:	total: 30.5s	remaining: 36.7s
# 454:	total: 30.6s	remaining: 36.6s
# 455:	total: 30.6s	remaining: 36.5s
# 456:	total: 30.7s	remaining: 36.5s
# 457:	total: 30.7s	remaining: 36.4s
# 458:	total: 30.8s	remaining: 36.3s
# 459:	total: 30.9s	remaining: 36.2s
# 460:	total: 30.9s	remaining: 36.1s
# 461:	total: 31s	remaining: 36.1s
# 462:	total: 31s	remaining: 36s
# 463:	total: 31.1s	remaining: 35.9s
# 464:	total: 31.2s	remaining: 35.8s
# 465:	total: 31.2s	remaining: 35.8s
# 466:	total: 31.3s	remaining: 35.7s
# 467:	total: 31.3s	remaining: 35.6s
# 468:	total: 31.4s	remaining: 35.5s
# 469:	total: 31.4s	remaining: 35.5s
# 470:	total: 31.5s	remaining: 35.4s
# 471:	total: 31.6s	remaining: 35.3s
# 472:	total: 31.6s	remaining: 35.2s
# 473:	total: 31.7s	remaining: 35.2s
# 474:	total: 31.8s	remaining: 35.1s
# 475:	total: 31.8s	remaining: 35s
# 476:	total: 31.9s	remaining: 35s
# 477:	total: 31.9s	remaining: 34.9s
# 478:	total: 32s	remaining: 34.8s
# 479:	total: 32.1s	remaining: 34.7s
# 480:	total: 32.1s	remaining: 34.6s
# 481:	total: 32.2s	remaining: 34.6s
# 482:	total: 32.2s	remaining: 34.5s
# 483:	total: 32.3s	remaining: 34.4s
# 484:	total: 32.3s	remaining: 34.3s
# 485:	total: 32.4s	remaining: 34.3s
# 486:	total: 32.5s	remaining: 34.2s
# 487:	total: 32.5s	remaining: 34.1s
# 488:	total: 32.6s	remaining: 34.1s
# 489:	total: 32.6s	remaining: 34s
# 490:	total: 32.7s	remaining: 33.9s
# 491:	total: 32.8s	remaining: 33.8s
# 492:	total: 32.8s	remaining: 33.7s
# 493:	total: 32.9s	remaining: 33.7s
# 494:	total: 32.9s	remaining: 33.6s
# 495:	total: 33s	remaining: 33.5s
# 496:	total: 33s	remaining: 33.4s
# 497:	total: 33.1s	remaining: 33.4s
# 498:	total: 33.2s	remaining: 33.3s
# 499:	total: 33.2s	remaining: 33.2s
# 500:	total: 33.3s	remaining: 33.2s
# 501:	total: 33.4s	remaining: 33.1s
# 502:	total: 33.4s	remaining: 33s
# 503:	total: 33.5s	remaining: 33s
# 504:	total: 33.5s	remaining: 32.9s
# 505:	total: 33.6s	remaining: 32.8s
# 506:	total: 33.7s	remaining: 32.7s
# 507:	total: 33.7s	remaining: 32.7s
# 508:	total: 33.8s	remaining: 32.6s
# 509:	total: 33.8s	remaining: 32.5s
# 510:	total: 33.9s	remaining: 32.4s
# 511:	total: 34s	remaining: 32.4s
# 512:	total: 34s	remaining: 32.3s
# 513:	total: 34.1s	remaining: 32.2s
# 514:	total: 34.2s	remaining: 32.2s
# 515:	total: 34.2s	remaining: 32.1s
# 516:	total: 34.3s	remaining: 32s
# 517:	total: 34.3s	remaining: 31.9s
# 518:	total: 34.4s	remaining: 31.9s
# 519:	total: 34.4s	remaining: 31.8s
# 520:	total: 34.5s	remaining: 31.7s
# 521:	total: 34.6s	remaining: 31.7s
# 522:	total: 34.6s	remaining: 31.6s
# 523:	total: 34.7s	remaining: 31.5s
# 524:	total: 34.8s	remaining: 31.4s
# 525:	total: 34.8s	remaining: 31.4s
# 526:	total: 34.9s	remaining: 31.3s
# 527:	total: 34.9s	remaining: 31.2s
# 528:	total: 35s	remaining: 31.2s
# 529:	total: 35.1s	remaining: 31.1s
# 530:	total: 35.1s	remaining: 31s
# 531:	total: 35.2s	remaining: 31s
# 532:	total: 35.3s	remaining: 30.9s
# 533:	total: 35.3s	remaining: 30.8s
# 534:	total: 35.4s	remaining: 30.8s
# 535:	total: 35.5s	remaining: 30.7s
# 536:	total: 35.6s	remaining: 30.7s
# 537:	total: 35.6s	remaining: 30.6s
# 538:	total: 35.7s	remaining: 30.5s
# 539:	total: 35.8s	remaining: 30.5s
# 540:	total: 35.9s	remaining: 30.4s
# 541:	total: 35.9s	remaining: 30.4s
# 542:	total: 36s	remaining: 30.3s
# 543:	total: 36.1s	remaining: 30.2s
# 544:	total: 36.1s	remaining: 30.2s
# 545:	total: 36.2s	remaining: 30.1s
# 546:	total: 36.3s	remaining: 30s
# 547:	total: 36.3s	remaining: 30s
# 548:	total: 36.4s	remaining: 29.9s
# 549:	total: 36.5s	remaining: 29.8s
# 550:	total: 36.5s	remaining: 29.8s
# 551:	total: 36.6s	remaining: 29.7s
# 552:	total: 36.6s	remaining: 29.6s
# 553:	total: 36.7s	remaining: 29.5s
# 554:	total: 36.8s	remaining: 29.5s
# 555:	total: 36.8s	remaining: 29.4s
# 556:	total: 36.9s	remaining: 29.3s
# 557:	total: 36.9s	remaining: 29.3s
# 558:	total: 37s	remaining: 29.2s
# 559:	total: 37.1s	remaining: 29.1s
# 560:	total: 37.1s	remaining: 29s
# 561:	total: 37.2s	remaining: 29s
# 562:	total: 37.2s	remaining: 28.9s
# 563:	total: 37.3s	remaining: 28.8s
# 564:	total: 37.3s	remaining: 28.8s
# 565:	total: 37.4s	remaining: 28.7s
# 566:	total: 37.5s	remaining: 28.6s
# 567:	total: 37.5s	remaining: 28.5s
# 568:	total: 37.6s	remaining: 28.5s
# 569:	total: 37.7s	remaining: 28.4s
# 570:	total: 37.7s	remaining: 28.3s
# 571:	total: 37.8s	remaining: 28.3s
# 572:	total: 37.8s	remaining: 28.2s
# 573:	total: 37.9s	remaining: 28.1s
# 574:	total: 38s	remaining: 28.1s
# 575:	total: 38s	remaining: 28s
# 576:	total: 38.1s	remaining: 27.9s
# 577:	total: 38.2s	remaining: 27.9s
# 578:	total: 38.2s	remaining: 27.8s
# 579:	total: 38.3s	remaining: 27.7s
# 580:	total: 38.3s	remaining: 27.6s
# 581:	total: 38.4s	remaining: 27.6s
# 582:	total: 38.5s	remaining: 27.5s
# 583:	total: 38.5s	remaining: 27.4s
# 584:	total: 38.6s	remaining: 27.4s
# 585:	total: 38.6s	remaining: 27.3s
# 586:	total: 38.7s	remaining: 27.2s
# 587:	total: 38.7s	remaining: 27.1s
# 588:	total: 38.8s	remaining: 27.1s
# 589:	total: 38.9s	remaining: 27s
# 590:	total: 38.9s	remaining: 26.9s
# 591:	total: 39s	remaining: 26.9s
# 592:	total: 39s	remaining: 26.8s
# 593:	total: 39.1s	remaining: 26.7s
# 594:	total: 39.2s	remaining: 26.7s
# 595:	total: 39.2s	remaining: 26.6s
# 596:	total: 39.3s	remaining: 26.5s
# 597:	total: 39.3s	remaining: 26.4s
# 598:	total: 39.4s	remaining: 26.4s
# 599:	total: 39.4s	remaining: 26.3s
# 600:	total: 39.5s	remaining: 26.2s
# 601:	total: 39.6s	remaining: 26.2s
# 602:	total: 39.6s	remaining: 26.1s
# 603:	total: 39.7s	remaining: 26s
# 604:	total: 39.7s	remaining: 25.9s
# 605:	total: 39.8s	remaining: 25.9s
# 606:	total: 39.9s	remaining: 25.8s
# 607:	total: 39.9s	remaining: 25.7s
# 608:	total: 40s	remaining: 25.7s
# 609:	total: 40.1s	remaining: 25.6s
# 610:	total: 40.1s	remaining: 25.5s
# 611:	total: 40.2s	remaining: 25.5s
# 612:	total: 40.2s	remaining: 25.4s
# 613:	total: 40.3s	remaining: 25.3s
# 614:	total: 40.3s	remaining: 25.3s
# 615:	total: 40.4s	remaining: 25.2s
# 616:	total: 40.5s	remaining: 25.1s
# 617:	total: 40.5s	remaining: 25s
# 618:	total: 40.6s	remaining: 25s
# 619:	total: 40.6s	remaining: 24.9s
# 620:	total: 40.7s	remaining: 24.8s
# 621:	total: 40.8s	remaining: 24.8s
# 622:	total: 40.8s	remaining: 24.7s
# 623:	total: 40.9s	remaining: 24.6s
# 624:	total: 40.9s	remaining: 24.6s
# 625:	total: 41s	remaining: 24.5s
# 626:	total: 41.1s	remaining: 24.4s
# 627:	total: 41.1s	remaining: 24.4s
# 628:	total: 41.2s	remaining: 24.3s
# 629:	total: 41.2s	remaining: 24.2s
# 630:	total: 41.3s	remaining: 24.1s
# 631:	total: 41.3s	remaining: 24.1s
# 632:	total: 41.4s	remaining: 24s
# 633:	total: 41.5s	remaining: 23.9s
# 634:	total: 41.5s	remaining: 23.9s
# 635:	total: 41.6s	remaining: 23.8s
# 636:	total: 41.6s	remaining: 23.7s
# 637:	total: 41.7s	remaining: 23.7s
# 638:	total: 41.8s	remaining: 23.6s
# 639:	total: 41.8s	remaining: 23.5s
# 640:	total: 41.9s	remaining: 23.5s
# 641:	total: 42s	remaining: 23.4s
# 642:	total: 42s	remaining: 23.3s
# 643:	total: 42.1s	remaining: 23.3s
# 644:	total: 42.1s	remaining: 23.2s
# 645:	total: 42.2s	remaining: 23.1s
# 646:	total: 42.3s	remaining: 23.1s
# 647:	total: 42.3s	remaining: 23s
# 648:	total: 42.4s	remaining: 22.9s
# 649:	total: 42.4s	remaining: 22.9s
# 650:	total: 42.5s	remaining: 22.8s
# 651:	total: 42.6s	remaining: 22.7s
# 652:	total: 42.6s	remaining: 22.6s
# 653:	total: 42.7s	remaining: 22.6s
# 654:	total: 42.7s	remaining: 22.5s
# 655:	total: 42.8s	remaining: 22.4s
# 656:	total: 42.9s	remaining: 22.4s
# 657:	total: 42.9s	remaining: 22.3s
# 658:	total: 43s	remaining: 22.2s
# 659:	total: 43s	remaining: 22.2s
# 660:	total: 43.1s	remaining: 22.1s
# 661:	total: 43.1s	remaining: 22s
# 662:	total: 43.2s	remaining: 22s
# 663:	total: 43.3s	remaining: 21.9s
# 664:	total: 43.3s	remaining: 21.8s
# 665:	total: 43.4s	remaining: 21.8s
# 666:	total: 43.4s	remaining: 21.7s
# 667:	total: 43.5s	remaining: 21.6s
# 668:	total: 43.6s	remaining: 21.6s
# 669:	total: 43.6s	remaining: 21.5s
# 670:	total: 43.7s	remaining: 21.4s
# 671:	total: 43.7s	remaining: 21.4s
# 672:	total: 43.8s	remaining: 21.3s
# 673:	total: 43.9s	remaining: 21.2s
# 674:	total: 43.9s	remaining: 21.1s
# 675:	total: 44s	remaining: 21.1s
# 676:	total: 44s	remaining: 21s
# 677:	total: 44.1s	remaining: 20.9s
# 678:	total: 44.2s	remaining: 20.9s
# 679:	total: 44.2s	remaining: 20.8s
# 680:	total: 44.3s	remaining: 20.7s
# 681:	total: 44.3s	remaining: 20.7s
# 682:	total: 44.4s	remaining: 20.6s
# 683:	total: 44.5s	remaining: 20.5s
# 684:	total: 44.5s	remaining: 20.5s
# 685:	total: 44.6s	remaining: 20.4s
# 686:	total: 44.6s	remaining: 20.3s
# 687:	total: 44.7s	remaining: 20.3s
# 688:	total: 44.7s	remaining: 20.2s
# 689:	total: 44.8s	remaining: 20.1s
# 690:	total: 44.9s	remaining: 20.1s
# 691:	total: 44.9s	remaining: 20s
# 692:	total: 45s	remaining: 19.9s
# 693:	total: 45s	remaining: 19.9s
# 694:	total: 45.1s	remaining: 19.8s
# 695:	total: 45.1s	remaining: 19.7s
# 696:	total: 45.2s	remaining: 19.6s
# 697:	total: 45.3s	remaining: 19.6s
# 698:	total: 45.3s	remaining: 19.5s
# 699:	total: 45.4s	remaining: 19.5s
# 700:	total: 45.4s	remaining: 19.4s
# 701:	total: 45.5s	remaining: 19.3s
# 702:	total: 45.6s	remaining: 19.3s
# 703:	total: 45.6s	remaining: 19.2s
# 704:	total: 45.7s	remaining: 19.1s
# 705:	total: 45.7s	remaining: 19s
# 706:	total: 45.8s	remaining: 19s
# 707:	total: 45.9s	remaining: 18.9s
# 708:	total: 45.9s	remaining: 18.8s
# 709:	total: 46s	remaining: 18.8s
# 710:	total: 46s	remaining: 18.7s
# 711:	total: 46.1s	remaining: 18.6s
# 712:	total: 46.2s	remaining: 18.6s
# 713:	total: 46.2s	remaining: 18.5s
# 714:	total: 46.3s	remaining: 18.4s
# 715:	total: 46.3s	remaining: 18.4s
# 716:	total: 46.4s	remaining: 18.3s
# 717:	total: 46.5s	remaining: 18.2s
# 718:	total: 46.5s	remaining: 18.2s
# 719:	total: 46.6s	remaining: 18.1s
# 720:	total: 46.6s	remaining: 18s
# 721:	total: 46.7s	remaining: 18s
# 722:	total: 46.7s	remaining: 17.9s
# 723:	total: 46.8s	remaining: 17.8s
# 724:	total: 46.8s	remaining: 17.8s
# 725:	total: 46.9s	remaining: 17.7s
# 726:	total: 47s	remaining: 17.6s
# 727:	total: 47s	remaining: 17.6s
# 728:	total: 47.1s	remaining: 17.5s
# 729:	total: 47.1s	remaining: 17.4s
# 730:	total: 47.2s	remaining: 17.4s
# 731:	total: 47.3s	remaining: 17.3s
# 732:	total: 47.3s	remaining: 17.2s
# 733:	total: 47.4s	remaining: 17.2s
# 734:	total: 47.4s	remaining: 17.1s
# 735:	total: 47.5s	remaining: 17s
# 736:	total: 47.6s	remaining: 17s
# 737:	total: 47.6s	remaining: 16.9s
# 738:	total: 47.7s	remaining: 16.8s
# 739:	total: 47.8s	remaining: 16.8s
# 740:	total: 47.8s	remaining: 16.7s
# 741:	total: 47.9s	remaining: 16.6s
# 742:	total: 47.9s	remaining: 16.6s
# 743:	total: 48s	remaining: 16.5s
# 744:	total: 48s	remaining: 16.4s
# 745:	total: 48.1s	remaining: 16.4s
# 746:	total: 48.2s	remaining: 16.3s
# 747:	total: 48.2s	remaining: 16.2s
# 748:	total: 48.3s	remaining: 16.2s
# 749:	total: 48.3s	remaining: 16.1s
# 750:	total: 48.4s	remaining: 16s
# 751:	total: 48.4s	remaining: 16s
# 752:	total: 48.5s	remaining: 15.9s
# 753:	total: 48.6s	remaining: 15.8s
# 754:	total: 48.6s	remaining: 15.8s
# 755:	total: 48.7s	remaining: 15.7s
# 756:	total: 48.8s	remaining: 15.7s
# 757:	total: 48.8s	remaining: 15.6s
# 758:	total: 48.9s	remaining: 15.5s
# 759:	total: 48.9s	remaining: 15.4s
# 760:	total: 49s	remaining: 15.4s
# 761:	total: 49s	remaining: 15.3s
# 762:	total: 49.1s	remaining: 15.3s
# 763:	total: 49.2s	remaining: 15.2s
# 764:	total: 49.2s	remaining: 15.1s
# 765:	total: 49.3s	remaining: 15.1s
# 766:	total: 49.3s	remaining: 15s
# 767:	total: 49.4s	remaining: 14.9s
# 768:	total: 49.5s	remaining: 14.9s
# 769:	total: 49.5s	remaining: 14.8s
# 770:	total: 49.6s	remaining: 14.7s
# 771:	total: 49.6s	remaining: 14.7s
# 772:	total: 49.7s	remaining: 14.6s
# 773:	total: 49.7s	remaining: 14.5s
# 774:	total: 49.8s	remaining: 14.5s
# 775:	total: 49.9s	remaining: 14.4s
# 776:	total: 49.9s	remaining: 14.3s
# 777:	total: 50s	remaining: 14.3s
# 778:	total: 50s	remaining: 14.2s
# 779:	total: 50.1s	remaining: 14.1s
# 780:	total: 50.2s	remaining: 14.1s
# 781:	total: 50.2s	remaining: 14s
# 782:	total: 50.3s	remaining: 13.9s
# 783:	total: 50.3s	remaining: 13.9s
# 784:	total: 50.4s	remaining: 13.8s
# 785:	total: 50.4s	remaining: 13.7s
# 786:	total: 50.5s	remaining: 13.7s
# 787:	total: 50.6s	remaining: 13.6s
# 788:	total: 50.6s	remaining: 13.5s
# 789:	total: 50.7s	remaining: 13.5s
# 790:	total: 50.8s	remaining: 13.4s
# 791:	total: 50.8s	remaining: 13.3s
# 792:	total: 50.9s	remaining: 13.3s
# 793:	total: 50.9s	remaining: 13.2s
# 794:	total: 51s	remaining: 13.1s
# 795:	total: 51.1s	remaining: 13.1s
# 796:	total: 51.1s	remaining: 13s
# 797:	total: 51.2s	remaining: 13s
# 798:	total: 51.3s	remaining: 12.9s
# 799:	total: 51.3s	remaining: 12.8s
# 800:	total: 51.4s	remaining: 12.8s
# 801:	total: 51.5s	remaining: 12.7s
# 802:	total: 51.6s	remaining: 12.7s
# 803:	total: 51.7s	remaining: 12.6s
# 804:	total: 51.7s	remaining: 12.5s
# 805:	total: 51.8s	remaining: 12.5s
# 806:	total: 51.9s	remaining: 12.4s
# 807:	total: 51.9s	remaining: 12.3s
# 808:	total: 52s	remaining: 12.3s
# 809:	total: 52.1s	remaining: 12.2s
# 810:	total: 52.1s	remaining: 12.2s
# 811:	total: 52.2s	remaining: 12.1s
# 812:	total: 52.3s	remaining: 12s
# 813:	total: 52.4s	remaining: 12s
# 814:	total: 52.4s	remaining: 11.9s
# 815:	total: 52.5s	remaining: 11.8s
# 816:	total: 52.5s	remaining: 11.8s
# 817:	total: 52.6s	remaining: 11.7s
# 818:	total: 52.7s	remaining: 11.6s
# 819:	total: 52.7s	remaining: 11.6s
# 820:	total: 52.8s	remaining: 11.5s
# 821:	total: 52.8s	remaining: 11.4s
# 822:	total: 52.9s	remaining: 11.4s
# 823:	total: 53s	remaining: 11.3s
# 824:	total: 53s	remaining: 11.2s
# 825:	total: 53.1s	remaining: 11.2s
# 826:	total: 53.1s	remaining: 11.1s
# 827:	total: 53.2s	remaining: 11s
# 828:	total: 53.2s	remaining: 11s
# 829:	total: 53.3s	remaining: 10.9s
# 830:	total: 53.4s	remaining: 10.9s
# 831:	total: 53.4s	remaining: 10.8s
# 832:	total: 53.5s	remaining: 10.7s
# 833:	total: 53.6s	remaining: 10.7s
# 834:	total: 53.6s	remaining: 10.6s
# 835:	total: 53.7s	remaining: 10.5s
# 836:	total: 53.7s	remaining: 10.5s
# 837:	total: 53.8s	remaining: 10.4s
# 838:	total: 53.9s	remaining: 10.3s
# 839:	total: 53.9s	remaining: 10.3s
# 840:	total: 54s	remaining: 10.2s
# 841:	total: 54s	remaining: 10.1s
# 842:	total: 54.1s	remaining: 10.1s
# 843:	total: 54.1s	remaining: 10s
# 844:	total: 54.2s	remaining: 9.94s
# 845:	total: 54.3s	remaining: 9.88s
# 846:	total: 54.3s	remaining: 9.81s
# 847:	total: 54.4s	remaining: 9.74s
# 848:	total: 54.4s	remaining: 9.68s
# 849:	total: 54.5s	remaining: 9.62s
# 850:	total: 54.5s	remaining: 9.55s
# 851:	total: 54.6s	remaining: 9.49s
# 852:	total: 54.7s	remaining: 9.42s
# 853:	total: 54.7s	remaining: 9.36s
# 854:	total: 54.8s	remaining: 9.29s
# 855:	total: 54.8s	remaining: 9.23s
# 856:	total: 54.9s	remaining: 9.16s
# 857:	total: 55s	remaining: 9.1s
# 858:	total: 55s	remaining: 9.03s
# 859:	total: 55.1s	remaining: 8.97s
# 860:	total: 55.2s	remaining: 8.9s
# 861:	total: 55.2s	remaining: 8.84s
# 862:	total: 55.3s	remaining: 8.77s
# 863:	total: 55.3s	remaining: 8.71s
# 864:	total: 55.4s	remaining: 8.64s
# 865:	total: 55.5s	remaining: 8.58s
# 866:	total: 55.5s	remaining: 8.52s
# 867:	total: 55.6s	remaining: 8.45s
# 868:	total: 55.6s	remaining: 8.39s
# 869:	total: 55.7s	remaining: 8.32s
# 870:	total: 55.8s	remaining: 8.26s
# 871:	total: 55.8s	remaining: 8.19s
# 872:	total: 55.9s	remaining: 8.13s
# 873:	total: 56s	remaining: 8.07s
# 874:	total: 56s	remaining: 8s
# 875:	total: 56.1s	remaining: 7.94s
# 876:	total: 56.1s	remaining: 7.87s
# 877:	total: 56.2s	remaining: 7.81s
# 878:	total: 56.3s	remaining: 7.74s
# 879:	total: 56.3s	remaining: 7.68s
# 880:	total: 56.4s	remaining: 7.61s
# 881:	total: 56.4s	remaining: 7.55s
# 882:	total: 56.5s	remaining: 7.49s
# 883:	total: 56.6s	remaining: 7.42s
# 884:	total: 56.6s	remaining: 7.36s
# 885:	total: 56.7s	remaining: 7.29s
# 886:	total: 56.7s	remaining: 7.23s
# 887:	total: 56.8s	remaining: 7.16s
# 888:	total: 56.8s	remaining: 7.1s
# 889:	total: 56.9s	remaining: 7.03s
# 890:	total: 57s	remaining: 6.97s
# 891:	total: 57s	remaining: 6.9s
# 892:	total: 57.1s	remaining: 6.84s
# 893:	total: 57.1s	remaining: 6.77s
# 894:	total: 57.2s	remaining: 6.71s
# 895:	total: 57.2s	remaining: 6.64s
# 896:	total: 57.3s	remaining: 6.58s
# 897:	total: 57.4s	remaining: 6.51s
# 898:	total: 57.4s	remaining: 6.45s
# 899:	total: 57.5s	remaining: 6.39s
# 900:	total: 57.5s	remaining: 6.32s
# 901:	total: 57.6s	remaining: 6.26s
# 902:	total: 57.7s	remaining: 6.19s
# 903:	total: 57.7s	remaining: 6.13s
# 904:	total: 57.8s	remaining: 6.07s
# 905:	total: 57.8s	remaining: 6s
# 906:	total: 57.9s	remaining: 5.94s
# 907:	total: 58s	remaining: 5.87s
# 908:	total: 58s	remaining: 5.81s
# 909:	total: 58.1s	remaining: 5.75s
# 910:	total: 58.2s	remaining: 5.68s
# 911:	total: 58.2s	remaining: 5.62s
# 912:	total: 58.3s	remaining: 5.55s
# 913:	total: 58.3s	remaining: 5.49s
# 914:	total: 58.4s	remaining: 5.42s
# 915:	total: 58.4s	remaining: 5.36s
# 916:	total: 58.5s	remaining: 5.29s
# 917:	total: 58.6s	remaining: 5.23s
# 918:	total: 58.6s	remaining: 5.17s
# 919:	total: 58.7s	remaining: 5.1s
# 920:	total: 58.7s	remaining: 5.04s
# 921:	total: 58.8s	remaining: 4.97s
# 922:	total: 58.8s	remaining: 4.91s
# 923:	total: 58.9s	remaining: 4.84s
# 924:	total: 59s	remaining: 4.78s
# 925:	total: 59s	remaining: 4.72s
# 926:	total: 59.1s	remaining: 4.65s
# 927:	total: 59.2s	remaining: 4.59s
# 928:	total: 59.2s	remaining: 4.53s
# 929:	total: 59.3s	remaining: 4.46s
# 930:	total: 59.3s	remaining: 4.4s
# 931:	total: 59.4s	remaining: 4.33s
# 932:	total: 59.5s	remaining: 4.27s
# 933:	total: 59.5s	remaining: 4.2s
# 934:	total: 59.6s	remaining: 4.14s
# 935:	total: 59.6s	remaining: 4.08s
# 936:	total: 59.7s	remaining: 4.01s
# 937:	total: 59.7s	remaining: 3.95s
# 938:	total: 59.8s	remaining: 3.88s
# 939:	total: 59.9s	remaining: 3.82s
# 940:	total: 59.9s	remaining: 3.76s
# 941:	total: 1m	remaining: 3.69s
# 942:	total: 1m	remaining: 3.63s
# 943:	total: 1m	remaining: 3.57s
# 944:	total: 1m	remaining: 3.5s
# 945:	total: 1m	remaining: 3.44s
# 946:	total: 1m	remaining: 3.38s
# 947:	total: 1m	remaining: 3.31s
# 948:	total: 1m	remaining: 3.25s
# 949:	total: 1m	remaining: 3.18s
# 950:	total: 1m	remaining: 3.12s
# 951:	total: 1m	remaining: 3.06s
# 952:	total: 1m	remaining: 2.99s
# 953:	total: 1m	remaining: 2.93s
# 954:	total: 1m	remaining: 2.86s
# 955:	total: 1m	remaining: 2.8s
# 956:	total: 1m	remaining: 2.73s
# 957:	total: 1m	remaining: 2.67s
# 958:	total: 1m 1s	remaining: 2.61s
# 959:	total: 1m 1s	remaining: 2.54s
# 960:	total: 1m 1s	remaining: 2.48s
# 961:	total: 1m 1s	remaining: 2.42s
# 962:	total: 1m 1s	remaining: 2.35s
# 963:	total: 1m 1s	remaining: 2.29s
# 964:	total: 1m 1s	remaining: 2.23s
# 965:	total: 1m 1s	remaining: 2.16s
# 966:	total: 1m 1s	remaining: 2.1s
# 967:	total: 1m 1s	remaining: 2.03s
# 968:	total: 1m 1s	remaining: 1.97s
# 969:	total: 1m 1s	remaining: 1.91s
# 970:	total: 1m 1s	remaining: 1.84s
# 971:	total: 1m 1s	remaining: 1.78s
# 972:	total: 1m 1s	remaining: 1.72s
# 973:	total: 1m 1s	remaining: 1.65s
# 974:	total: 1m 1s	remaining: 1.59s
# 975:	total: 1m 2s	remaining: 1.52s
# 976:	total: 1m 2s	remaining: 1.46s
# 977:	total: 1m 2s	remaining: 1.4s
# 978:	total: 1m 2s	remaining: 1.33s
# 979:	total: 1m 2s	remaining: 1.27s
# 980:	total: 1m 2s	remaining: 1.21s
# 981:	total: 1m 2s	remaining: 1.14s
# 982:	total: 1m 2s	remaining: 1.08s
# 983:	total: 1m 2s	remaining: 1.01s
# 984:	total: 1m 2s	remaining: 952ms
# 985:	total: 1m 2s	remaining: 888ms
# 986:	total: 1m 2s	remaining: 825ms
# 987:	total: 1m 2s	remaining: 761ms
# 988:	total: 1m 2s	remaining: 698ms
# 989:	total: 1m 2s	remaining: 634ms
# 990:	total: 1m 2s	remaining: 571ms
# 991:	total: 1m 2s	remaining: 507ms
# 992:	total: 1m 2s	remaining: 444ms
# 993:	total: 1m 3s	remaining: 381ms
# 994:	total: 1m 3s	remaining: 317ms
# 995:	total: 1m 3s	remaining: 254ms
# 996:	total: 1m 3s	remaining: 190ms
# 997:	total: 1m 3s	remaining: 127ms
# 998:	total: 1m 3s	remaining: 63.4ms
# 999:	total: 1m 3s	remaining: 0us
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columnselector',
#                                   ColumnSelector(columns={'0', '1', '10', '100',
#                                                           '101', '102', '103',
#                                                           '104', '105', '106',
#                                                           '107', '108', '109',
#                                                           '11', '110', '111',
#                                                           '112', '113', '114',
#                                                           '115', '116', '117',
#                                                           '118', '119', '12',
#                                                           '120', '121', '122',
#                                                           '123', '124', ...})),
#                                  ('featureunion',
#                                   FeatureUnion(transformer_list=[('numeric_features',
#                                                                   Pipeline(steps=[(...
#                                                                                                            '32',
#                                                                                                            '33',
#                                                                                                            '57',
#                                                                                                            '95',
#                                                                                                            'week_on_month'})),
#                                                                                   ('simpleimputer',
#                                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                                   ('onehotencoder',
#                                                                                    OneHotEncoder(handle_unknown='ignore'))])),
#                                                                  ('boolean_features',
#                                                                   Pipeline(steps=[('columnselector',
#                                                                                    ColumnSelector(columns={'not_first_offer'}))]))]))])),
#                 ('catboostclassifier',
#                  <catboost.core.CatBoostClassifier object at 0x000002B9CF163CA0>)])

# %%
preds_train = cat_boost_pipe.predict(X_train)
f1_score(Y_train, preds_train, average='macro')
# Out:
# 0.8861118699005465

# %%
preds_test = cat_boost_pipe.predict(X_test)
f1_score(Y_test, preds_test, average='macro')
# Out:
# 0.7312543163352377

# %%
print(classification_report(Y_test, preds_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.92    153403
#          1.0       0.37      1.00      0.54     12928
#
#     accuracy                           0.87    166331
#    macro avg       0.68      0.93      0.73    166331
# weighted avg       0.95      0.87      0.89    166331

# %%
with open('data/cat_boost_model.pickle', 'wb') as f:
    pickle.dump(cat_boost_pipe, f, protocol=pickle.HIGHEST_PROTOCOL)
